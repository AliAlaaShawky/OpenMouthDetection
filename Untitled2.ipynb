# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.resnet import ResNet
from keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
INIT_LR = 1e-4
EPOCHS = 20
BS = 32

# %%
DIRECTORY = r"C:/Users/xps/Desktop/mouth/dataset"
CATEGORIES = ["silent", "speak"]

# %%
data = []
labels = []

for category in CATEGORIES:
    path = os.path.join(DIRECTORY, category)
    for img in os.listdir(path):
            img_path = os.path.join(path, img)
            image = load_img(img_path, target_size=(224, 224))
            image = img_to_array(image)
            image = preprocess_input(image)

            data.append(image)
            labels.append(category)

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

data = np.array(data, dtype="float32")
labels = np.array(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels,
        test_size=0.20, stratify=labels, random_state=42)

# %%
aug = ImageDataGenerator(
        rotation_range=20,
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest")

# %%
baseModel = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

# %%
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# %%
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %%
# compile model
print("[INFO] compiling model...")
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
    metrics=["accuracy"])
# Out:
# [INFO] compiling model...
# c:\Users\xps\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# train the head of the network
print("[INFO] training head...")
H = model.fit(
        aug.flow(trainX, trainY, batch_size=BS),
        steps_per_epoch=len(trainX) // BS,
        validation_data=(testX, testY),
        validation_steps=len(testX) // BS,
        epochs=EPOCHS)
# Out:
# [INFO] training head...
# Epoch 1/20
# 98/98 [==============================] - 1275s 13s/step - loss: 0.0935 - accuracy: 0.9668 - val_loss: 6.3381e-04 - val_accuracy: 1.0000
# Epoch 2/20
# 98/98 [==============================] - 1225s 13s/step - loss: 0.0159 - accuracy: 0.9955 - val_loss: 5.2294e-05 - val_accuracy: 1.0000
# Epoch 3/20
# 98/98 [==============================] - 1209s 12s/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 5.2303e-05 - val_accuracy: 1.0000
# Epoch 4/20
# 98/98 [==============================] - 1238s 13s/step - loss: 9.1777e-04 - accuracy: 1.0000 - val_loss: 1.0108e-05 - val_accuracy: 1.0000
# Epoch 5/20
# 98/98 [==============================] - 1198s 12s/step - loss: 0.0290 - accuracy: 0.9920 - val_loss: 0.6698 - val_accuracy: 0.8293
# Epoch 6/20
# 98/98 [==============================] - 1132s 12s/step - loss: 0.0200 - accuracy: 0.9968 - val_loss: 0.0716 - val_accuracy: 0.9796
# Epoch 7/20
# 98/98 [==============================] - 1405s 14s/step - loss: 0.0261 - accuracy: 0.9939 - val_loss: 0.0317 - val_accuracy: 0.9885
# Epoch 8/20
# 98/98 [==============================] - 1318s 13s/step - loss: 0.0075 - accuracy: 0.9994 - val_loss: 0.0079 - val_accuracy: 0.9962
# Epoch 9/20
# 98/98 [==============================] - 1296s 13s/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 0.0202 - val_accuracy: 0.9911
# Epoch 10/20
# 98/98 [==============================] - 1205s 12s/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 3.2571e-04 - val_accuracy: 1.0000
# Epoch 11/20
# 98/98 [==============================] - 1175s 12s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.6295e-05 - val_accuracy: 1.0000
# Epoch 12/20
# 98/98 [==============================] - 1105s 11s/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 1.0217 - val_accuracy: 0.8115
# Epoch 13/20
# 98/98 [==============================] - 1113s 11s/step - loss: 0.0107 - accuracy: 0.9987 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 14/20
# 98/98 [==============================] - 1132s 12s/step - loss: 0.0177 - accuracy: 0.9968 - val_loss: 0.1243 - val_accuracy: 0.9847
# Epoch 15/20
# 98/98 [==============================] - 1364s 14s/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 9.4563e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 98/98 [==============================] - 1313s 13s/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 4.5299e-04 - val_accuracy: 1.0000
# Epoch 17/20
# 98/98 [==============================] - 1282s 13s/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 1.1354e-04 - val_accuracy: 1.0000
# Epoch 18/20
# 98/98 [==============================] - 1359s 14s/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 1.1082e-04 - val_accuracy: 1.0000
# Epoch 19/20
# 98/98 [==============================] - 1239s 13s/step - loss: 5.1698e-04 - accuracy: 1.0000 - val_loss: 3.5273e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 98/98 [==============================] - 1243s 13s/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 1.2393 - val_accuracy: 0.9134

# %%
predIdxs = model.predict(testX, batch_size=BS)

# %%
predIdxs = np.argmax(predIdxs, axis=1)

# %%
print(classification_report(testY.argmax(axis=1), predIdxs,
	target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#       silent       1.00      0.82      0.90       384
#        speak       0.86      1.00      0.92       401
#
#     accuracy                           0.91       785
#    macro avg       0.93      0.91      0.91       785
# weighted avg       0.93      0.91      0.91       785

# %%
print("[INFO] saving mask detector model...")
model.save("ResNet50.model", save_format="h5")
# Out:
# [INFO] saving mask detector model...

# %%
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")

# %%
from keras.preprocessing import image
from keras.models import load_model
from keras.applications import imagenet_utils
import numpy as np
def prepare_image(file):
    img = image.load_img( file, target_size=(224,224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array,axis=0)
    return preprocess_input(img_array_expanded_dims)
validpath=r'C:/Users/xps/Desktop/CNN-task/valid'
import cv2
import glob as gb
x_valid=[]
mobile=load_model("ResNet50.model")
class_labels=['Mask' ,'Without Mask']
files=gb.glob(pathname=str(validpath+'/*.jpg'))
x=0
title=[]
for file in files :
    preprocessed_image = prepare_image(file)
    predictions = mobile.predict(preprocessed_image)
    for pred in predictions:
        (mask, withoutMask) = pred
        label = "Mask" if mask > withoutMask else "No Mask"
    label = "{}: {:.2f}%".format(label, max(mask, withoutMask) * 100)
    title.append(label)
    image_plot=cv2.imread(file)
    x_valid.append(cv2.resize(image_plot,(120,120)))
    x=x+1
for c in range(0,x):  
    x_valid=np.array(x_valid)
    plt.figure(figsize=(20,20))
    plt.subplot(6,6,3)
    plt.imshow(x_valid[c])
    plt.axis('off')
    plt.title(title[c])
# Out:
# C:\Users\xps\AppData\Local\Temp/ipykernel_3884/4015034922.py:32: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20,20))
